# %%
import requests
import json

# %%
import pandas as pd
md_biz = pd.read_csv('md_biz_reviews')

# %%
import sys
print(sys.path)
# Out:
# ['/Users/gschwaeber/Documents/Data_Science/Flatiron/Yelp_Project', '/opt/anaconda3/lib/python38.zip', '/opt/anaconda3/lib/python3.8', '/opt/anaconda3/lib/python3.8/lib-dynload', '', '/opt/anaconda3/lib/python3.8/site-packages', '/opt/anaconda3/lib/python3.8/site-packages/aeosa', '/opt/anaconda3/lib/python3.8/site-packages/IPython/extensions', '/Users/gschwaeber/.ipython']

# %%
#client_id = ____
api_key = 'LhS2ngYnwSzqloedf_iYxOqy1PECULP4SywXGI_YjvcCJW_Wk9QtoXbU-VSMvs67ppcKRqWADEzJzmHYes5HRg_MvYWS9ABf2e-QEk46KCcqdNZu-hj3AUJ6mZsmYHYx'

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %%
response = requests.get(url, headers=headers)
#N:request package 
#N:created headers above
#N:create web addres gives us all
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-38a030fd82ec> in <module>
# ----> 1 response = requests.get(url, headers=headers)
#       2 #N:request package
#       3 #N:created headers above
#       4 #N:create web addres gives us all
#
# NameError: name 'url' is not defined

# %%
def yelp_call(url_param):
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()['businesses']

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    reviews = []
    # loop through our business and 
    for review in list_of_data:
    # parse each individual business into a tuple
        review_tuple = (review['rating'], 
                        review['text'])
    # add each individual business tuple to our data container
        reviews.append(review_tuple)
    # return the container with all of the parsed results
    return reviews

# %%
for business in biz_info['id']: 
    url =  'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
    response = requests.get(url, headers=headers)
    data = response.json()
    parse_data(data['reviews'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-9c165b9ba426> in <module>
# ----> 1 for business in biz_info['id']:
#       2     url =  'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
#       3     response = requests.get(url, headers=headers)
#       4     data = response.json()
#       5     parse_data(data['reviews'])
#
# NameError: name 'biz_info' is not defined

# %%
md_biz
# Out:
#      Unnamed: 0                      id                           Name  \
# 0             0  smTFfg1g_BjsUkorL_ZxLQ         Kuya Ja's Lechon Belly
# 1             1  9nhzaAX6BdbgF4u2Zxi9RA                         Kusshi
# 2             2  OaI2Mh2fXj_RUq7hnGV_iQ                           Nada
# 3             3  UYffA9zyxFnu8E0T2hqoNw          Akira Ramen & Izakaya
# 4             4  ExMamAA8DqKpvwupNLdCgQ      KPOT Korean BBQ & Hot Pot
# ..          ...                     ...                            ...
# 604         604  4RTWtfGw-QNL7pYj6rMpAQ  Serengeti Resturaunt & Lounge
# 605         605  joY2tjvlNqrdPfk0UTW4IQ                Country Chicken
# 606         606  AZQn_LIn650udstIkfsi8g                   Capital Bleu
# 607         607  QJrfHhz7XecrmFMcPXGljQ                   Betty's Gojo
# 608         608  xENeN16taYu0UkqNr_XyOQ   Danibelle's Lebanese Cuisine
#
#      Review_Count                                  Categories  Rating Price  \
# 0             593                                ['Filipino']     4.5    $$
# 1             486  ['Sushi Bars', 'Japanese', 'Whiskey Bars']     4.5    $$
# 2             447           ['Breakfast & Brunch', 'Mexican']     4.0    $$
# 3             707                        ['Izakaya', 'Ramen']     4.0    $$
# 4             634             ['Barbeque', 'Hot Pot', 'Bars']     4.0    $$
# ..            ...                                         ...     ...   ...
# 604             5                      ['African', 'Lounges']     2.5    $$
# 605             3                           ['Chicken Wings']     2.0    $$
# 606             3                          ['American (New)']     1.5   $$$
# 607             4                ['Ethiopian', 'Hookah Bars']     2.0    $$
# 608            21                 ['Lebanese', 'Food Trucks']     3.0    $$
#
#                                                Address
# 0       ['5268-H Nicholson Ln', 'Rockville, MD 20895']
# 1            ['11826 Trade St', 'Rockville, MD 20852']
# 2    ['11886 Grand Park Ave', 'North Bethesda, MD 2...
# 3    ['1800 Rockville Pike', 'Unit H1', 'Rockville,...
# 4          ['5550 Randolph Rd', 'Rockville, MD 20852']
# ..                                                 ...
# 604    ['6210 Georgia Ave NW', 'Washington, DC 20011']
# 605  ['11216 Grandview Ave', 'Silver Spring, MD 209...
# 606  ['8727 Colesville Rd', 'Silver Spring, MD 20910']
# 607    ['7616 Georgia Ave NW', 'Washington, DC 20012']
# 608   ['3879 Fort Worth Hwy', 'Weatherford, TX 76087']
#
# [609 rows x 8 columns]

# %%
total_data = []
for business in md_biz.loc[:,'id']:
    url = 'https://api.yelp.com/v3/businesses/{}/reviews'.format(business)
    response = requests.get(url, headers=headers)
    data = response.json()
    try:
        rev1 = data['reviews'][1]['text']
        rat1 = data['reviews'][1]['rating']
        rev2 = data['reviews'][2]['text']
        rat2 = data['reviews'][2]['rating']
    except:
        rev1 = None
        rat1 = None
        rev2 = None
        rat2 = None
    biz_tuple =(business,
               data['reviews'][0]['rating'],
               data['reviews'][0]['text'],
               rat1,
               rev1,
               rat2,
               rev2)
    total_data.append(biz_tuple)

# %%
total_data
# Out:
# [('14Z5fHYBRI8RLwTJGBbY6w',
#   5,
#   'Ok, so in the days of well now you worry about outside seating and social distancing.\n\nHunters has comfortable outdoor seating.\n\nI ordered the Fish and...',
#   5,
#   'We have ordered from here several times during COVID and have not been disappointed. The food is consistently great and comes just as we order it. This is...',
#   1,
#   'I came to pick a Grubhub order and one of the waitress was so impolite, disrespectful, and racist with just because I am Latino. I will never stop there...'),
#  ('MPPROfyyB9KGRlVO2DB3dA',
#   5,
#   'I came here for my birthday happy hour just my boyfriend and I. Practicing social distancing and trying to h set some good drinks. \n\nTheir happy hour...',
#   4,
#   "I've been here a few times and had a good experience. \n\nThe first time was for date night and we ordered the meat mountain. Everything was tasty, the...",
#   5,
#   'Pre-COVID, my husband and I enjoyed walking next door to Urban Butcher for their happy hour menu (hello lavender margaritas and a mini meat mountain) and...'),
#  ('LbPFrZqFjc8TTcxkehfjRw',
#   5,
#   'I LOVE SPROUT. \n\nFood: 5/5 Service: 5/5 \n\nFood: I love the variety of the food at Sprout. I typically do a sandwich or a panini and sushi. Favorite...',
#   3,
#   "I really want to say you should come out of your way to visit this place, but this isn't one of those places.  You know the million sandwich shops that...",
#   3,
#   "This place just officially opened last week (although I've been able to buy packaged snacks here for a couple weeks). It's clean, and new inside. This is as..."),
#  ('361TL_CyO-4CuR4_KN7pKQ',
#   5,
#   'Maria and her team pulled out all the stops to feed our team. We wanted a team meeting over lunch and wanted something different.  \n\nWe got a wide selection...',
#   1,
#   "Ok I don't even know how to begin. First of all lazy. Yep I said it ya didn't even try to make fried fish like to be honest I feel like you should pay me...",
#   4,
#   'This place was great for grab and go. No frills, The sea food  is fresh and the fried fish has a nice batter. You can get a fish sandwich to a dinner combo....'),
#  ('BVpWHObDjpEc4AerPfMLOg',
#   3,
#   'The Manager sells stale produce and over charges for baked goods.  I called to reserve some Monkey Bread and cookies for Christmas.  They usually have a...',
#   3,
#   'Excellent coffee to go (especially loved the cream)\n\nCherry danish looked better than it tasted. Not too much cherry flavor, but the cherries were there....',
#   2,
#   'The coffee was good but my cheese danish was cold and hard. This was after asking for it to be heated up. Also the service was mediocre. He dumped my...'),
#  ('f82G2WYrCbUMAdC27lCWyA',
#   5,
#   'We ordered several days worth of food today from Tally-Ho. It all looks wonderful. The meal lovers pizza was the heaviest pizza I had ever bought. It was...',
#   5,
#   'My family and I take out from here often whenever we want pizza or salad. If we order pizza, it is usually an entire pizza so it is hot and fresh out of the...',
#   5,
#   'We love picking up food from Tally-Ho. They are very responsive to take orders over the phone, and everything is always ready on time. They have an...'),
#  ('kw38xSRMFs5xtbKO2lH38Q',
#   4,
#   "Super fan of this place, newly discovered for me. I've seen it before, but never went in to try their food until my friend decided to stop by (we were close...",
#   4,
#   "Have been coming for their Tuesday $6.99 burrito/salad special almost every week of the covid lockout since its cheap and a lot of food (it's  always at...",
#   4,
#   'Did a curbside pick up of a burrito guacamole and lime pie.  Service was great.  Half of the food will make another meal.  The sweet pork, rice and black...'),
#  ('_RTrvW7KC9KiWUIjQbnP4w',
#   4,
#   "I'm happy Mix is open and operating safely during these Covid times. It's not easy to stay open during a pandemic, but Mix seems to be taking proper...",
#   4,
#   'My bf decided to take me out to this spot for our weekly date during COVID. This place was not pack and they were practicing social distancing and had...',
#   5,
#   'After stoping by 3 places around I finally found it on good and called and  for my lucky this place was open for patio dining... looked on Yelp mas it is...'),
#  ('EdiApxmcQbFu2p2MC6M6qA',
#   5,
#   "This food truck has started popping up around my office lately.  A coworker told me about it, and I initially looked for it and couldn't find it.  But now I...",
#   1,
#   '$15 for a tiny cup of collard greens and burnt tasting turkey gumbo!!!! I thinks not. Not good at all',
#   5,
#   "I love this spot it reminds me of that southern cooking u can't find at a restaurant but more like At your grandmothers house. The lasagna is what's really..."),
#  ('6ipL2CR7dh_LRepHbX6GcQ',
#   5,
#   'We came back for dinner and it was again excellent. We had the watercress guacamole, the hummus, the lamb meatballs, the shrimp tacos and the beet falafel...',
#   5,
#   "We've ordered takeout a few times in the last couple covid months and it's been delicious every time! We love the black bean burger (comes with sweet...",
#   5,
#   "Great for happy hour! Id been waiting for this restaurant to open for months and was not disappointed. Everything I've tried on the menu has been delicious..."),
#  ('0lFVAMfIcSQatHGzEqrr4w',
#   5,
#   'I have been going here for years because it is convenient and reliable.  Friendly staff, good food, quick service at a fair price.  I particularly like the...',
#   5,
#   "I work at the bank across the street and this is a hot spot for an easy quick lunch!  You can call ahead to have your order ready and they don't require...",
#   4,
#   'This is the cutest little sandwich shop in Rockville, MD! I found this restaurant on my Yelp app and called ahead to order a chicken salad sandwich. I did...'),
#  ('DjUJwGR19fzDvOkUY4uvcA',
#   5,
#   'About this place you have to visit one time, I love this restaurant this is one of my favorite late night restaurant I been here more than 20 times I never...',
#   4,
#   "This will be my third time coming here. Anyway, I came out for a friend's birthday event and decided to order a beef noodle soup. I must say, OH BOY!!!! I...",
#   4,
#   'We three people sang from 8pm - 12am, got 10 bottles of water, no food ordered, and paid $160 in total. Medium price, neither too high nor low. Service was...'),
#  ('gVWSphswCkNqD9uokUOKIA',
#   3,
#   "Came in for lunch and lunch menu was deceiving it states include soft drink but wasn't included and although I  appreciate how fast the food came which was...",
#   1,
#   "This was extremely disappointing.  Bland. No sauce  they say they meal has a drink included but it was just a warm bottle of Costco water.  I wouldn't even...",
#   5,
#   "I was kind of wary of trying this place due to mixed reviews but I'm glad I did. My brother and I were craving authentic Chinese skewers and while they're..."),
#  ('JndzI63laFLapKi9Tus5cg',
#   4,
#   'This is the place to go for a quick bite. Very tasty food and pleasant ambiance. The service is usually fast. My kids love this place.\n\nThe only negative...',
#   4,
#   'It was nearly midnight on a Saturday night. There were only a few tables of people and it was as really quite empty... but the place was rockin! The music...',
#   2,
#   'Good food, but the service was pretty terrible. I met a friend and arrived before she did, so I snagged a table. They quickly brought chips and a drink and...'),
#  ('e84sNgV1RbgmtGAIAxQRgA',
#   5,
#   "I've been eating at this Boston Market since I was a little kid, no joke! Before it was bought by McDonalds. \n\nIf you've never visited the Boston Market...",
#   2,
#   "Curbside was anything but. Didn't answer the phone. Had to go in (even though they said it wasn't an option). Food still wasn't ready 15 minutes after it...",
#   5,
#   "Aspen Hill location has done it again! Had a long day and needed to get dinner together for my family after 9, but we all still wanted a meal that wasn't..."),
#  ('qhh9gxWtdjBN3CQXMjjfsQ',
#   4,
#   "This is my new go to Kabob stop. From the outside it looks like just a small market. I've read the reviews about this place and always meant to stop in. One...",
#   5,
#   "I've ordered food for lunch here and they have the best Persian kabobs in the area. Would definitely recommend for anyone to try it. There is really limited...",
#   5,
#   'Hands down this place has one of the best Iranian foods that you could eat . The store is super clean and the staff was super friendly and helpful with me....'),
#  ('mLxK8H0ixnjkdUvXvUe2bw',
#   4,
#   "I've ordered from China Cafe numerous times in the past several months and love their consistency and quality of service and food. \n\nIf you order lunch...",
#   4,
#   "There is a real lack of solid Chinese Food in Bethesda. I'm sorry, I've lived here for close to 7 years now, and it's always something that's just been...",
#   5,
#   "Whenever I don't feel like cooking after a long day of work, I know I can count on this place to give me my fill. The auntie at this restaurant is so so..."),
#  ('he5lVUKgvlGmjMeWjLnO8A',
#   5,
#   "Sold. I don't have a single negative thing to say.\n\n- Food quality: juicy, fresh fish with warm sticky rice. All the other stuff they put in with it is...",
#   4,
#   "Follow their cool truck around Northern, VA as their musubi and poke is legit and that good! \n\nI've first followed them to a festival in Fairfax City to try...",
#   4,
#   "Track their location on their instagram page! Lucky for me, their locations tend to be close to my office, and my home.\n\nI've tried Poke-Man Truck a couple..."),
#  ('s1bt7NlU1wTQfgdMkN5x4A',
#   3,
#   'The only reason that I am rating this location 3 stars is because I always order from here, but they NEVER give me extra sauces when I ask for them....',
#   1,
#   "It's very rare that I come on here to leave any vitriol towards any establishment, but I call it like I see it. \n\nI walk in to place my order and a very...",
#   4,
#   'Great pizza and service. While I might normally think of it as being a little overpriced, the check in deal made it worth it. The only thing stopping this...'),
#  ('BwpMPsnE9XJnjhucvPtYng',
#   3,
#   'Never know when this place is open but the food is decent.  I was shocked to find out that the H St. location closed\u200d',
#   2,
#   'I I am a foodie!!  AND...I am a fan of hole in the wall restaurants.  This is where you find the best food.  \n\nWell, I was told to try Horace & Dickies (as...',
#   1,
#   "OH MY GOD- STAY AWAY FROM THESE PEOPLE! ITs sad you can't patronize a black business because of such unprofessionalism... I Would even go on the limb and..."),
#  ('mOM93xGUOMedMOD_brs2lQ',
#   4,
#   'Saritas and the surrounding shopping mall is as if a little bit of Latin America was dropped right into the US. The one server that speaks the best English...',
#   5,
#   "This is a great Peruvian restaurant! I've been to several Peruvian restaurants in the DMV area, but hadn't came here yet. There always seems to be a fault...",
#   1,
#   'I am not sure if we tried this place on a bad but the food was just horrible. The chicken was so salty that we ended up throwing it away once we got home. I...'),
#  ('lVZNX3vzDprg4jZTctTIMA',
#   4,
#   'I have not been to DC lately, but when I go there to visit family, a stop at Takoma Station is always on my schedule. This is a spot where you can get local...',
#   5,
#   "Let's end the decade on a classic note! Takoma Station Tavern is as classic a place that I literally can recall. This minority owed establishment has been a...",
#   2,
#   "I was really upset with the brisket sandwich. It was cold, chewy, had no smokey flavor and didn't include any extra sauce to place on the sandwich. I'm not..."),
#  ('dmWA-jxeC_8w2SviLDXWxw',
#   4,
#   'One can never go wrong with a healthy salad which can be made every which way per your palate. \n\n1. Choose Greenery\n2. Choose Toppings aka...',
#   5,
#   'Is it possible to crave Salads? I think so as I really enjoy handcrafted salads. My go to place is Sweetgreen, as they had a location everywhere when I...',
#   1,
#   'Terrible experience!  Ordered a "Mediterranean Salad" for delivery.  Not only did it arrive to me cold and more than 30 minutes late, but it was the WRONG...'),
#  ('BEztEUY45FifHkSR8_CsxQ',
#   4,
#   'This is my first time here and I have mixed feeling about this place. \n\nNothing fancy or special about this place just a regular hispanic bakery,( for the...',
#   4,
#   'A cute mom and pop bakery off of Viersmill with a small selection of Latin comfort food and pastries. My friends and I stumbled in here for some coffee and...',
#   3,
#   "Tres Leches barely has any milk in it. Disappointed as I'm used to Tres Leches saturated with milk.\n\nThe cake itself was good, just dry for a Tres Leches."),
#  ('canGGUCtoW_i4kQGiwnamg',
#   3,
#   'I am upgrading this to a 3-star experience because we ate at home thanks to the pandemic and UberEats. The Family Fests/packages during COVID are...',
#   4,
#   'I appreciate management for reaching out to discuss my initial review of the lack of quality control at the silver Spring MD location. Apparently something...',
#   5,
#   'So red lobster gave me a free appetizer. Came and got the Apple crissada* . It was delicious. Apples paired with sugar and vanilla icecream with a succulent...'),
#  ('0fTXxnjCajmyLUOQCmNtzA',
#   4,
#   "I prefer this location to others in the area. The parking lot is huge and doesn't technically share it with any other businesses. During Covid the carts are...",
#   4,
#   'Did Giant Pickup and was so pleased with the service and packing of the food (everything was categorized and eggs were clearly labeled)\n\nMy only complain...',
#   4,
#   'Very pleased with my experience at Giant. Perhaps my favorite thing about Giant is the free electric charging spot right at the front of the parking lot....'),
#  ('LjjQnGdolSMdbgjo6V94rw',
#   5,
#   "Cassava leaves with beef and white rice so delicious. I'm glad to see them back open!",
#   3,
#   'To begin, I heard many good things about this place as a lounge and decided to stop in for dinner (we are a family with young children). \n\nWe went to Golf...',
#   1,
#   'We are charged an entrance fee on Wednesday, $10 for each... cool we pay it although nobody else on the same strip is charging to enter. \nHowever, I go to...'),
#  ('kmaI2KNOYMTgILkBWcm4wA',
#   5,
#   'Update - been here many many times since first finding them in 2017 and continue to love it. \n\n Originally at the truck back at the garden center, then the...',
#   5,
#   'Amazing barbecue for this far north and really nice folks. We are a small family so ordered for Thanksgiving and it was perfect; we just made the sides....',
#   5,
#   "After living in Texas for several years, I refused to believe I would ever find a BBQ spot in Maryland that could compare...until I had Wieland's last..."),
#  ('QMVY4XCRljArHWMuca68MA',
#   4,
#   "Standard Sarku chain restaurant, just as a store layout rather than a stand like Wheaton mall. It's located in Aspen Hill's shopping center and for a...",
#   3,
#   'I was pleasantly surprised with this restaurant as I only know the ones in mall food courts which exclusively sell teriyaki chicken. \n\nWhile they still...',
#   2,
#   'I gave them a try with my open heart as my initial thought was "whoa it\'s not in a mall maybe the storefront location is different!" Nope. I was totally...'),
#  ('66N_hUkKI2WJDTFOZFlY2g',
#   5,
#   "So I've been here about 5-10 times so far. Can't remember exactly because of the pandemic. Nonetheless, decent beer selection and servers are always happy...",
#   4,
#   'One of my favorite places to go. The food was delicious! The brunch menus featured the cranberry mojito, lox n roll flatbread, and filet mignon sliders. You...',
#   5,
#   'This was the first restaurant we have been to since March and we were nervous to go. I was so pleasantly surprised about how safe the restaurant was. We sat...'),
#  ('GGwS5gHYvt1RePYUrXNEIw',
#   5,
#   'I love Kosher Kitchen for Many reasons. The food is always delicious. The staff is lovely.  Michael Medina he is a great manger and has alway high quality...',
#   5,
#   'I am eating now good from the Kosher Kitchen. It is so delicious that I decided to write a review right away!!\nThe boneless short ribs are the best......',
#   5,
#   'The Kosher Kitchen is out of the world wonderful! What an amazing lunch.  The taste and presentation - superb quality.  Thank you Michael and your team for...'),
#  ('6A64YPDd83_aiXKJMNp-Vw',
#   4,
#   'I ordered lunch from here using the Yelp app. The food came much sooner than I expected and it was great. They also remembered to add utensils, napkins and...',
#   1,
#   "WHY ON EARTH IS THIS RESTAURANT STILL OPEN. I'll like to start off by saying they speak great English and understood my order...28 minutes later I opened my...",
#   5,
#   "The beef quesadilla is absolutely outstanding! And for the price it's more than outstanding!!!"),
#  ('fsUvt03FD3cTiMjFLrI9Wg',
#   4,
#   'EXPERIENCE: I ordered online and picked it up myself. It was relevantly quick and the woman who handed my food after asking for my name gave me a smile....',
#   1,
#   "This was ordered for an office training at work. Very disappointing. $6 for a container of vegetable soup (I couldn't find any crab meat).",
#   1,
#   "Had to order through Doordash. After picking up order, & getting home, one sandwich was not in bag. Went back to resolve, no apology. 2 sandwiches didn't..."),
#  ('Lphs-CFBZ2z1Y1CoNUiGdw',
#   4,
#   'This establishment is definitely a hidden gem in Silver Spring. They serve food until they close at 1am on the weekends (this is somewhat of a big deal in...',
#   4,
#   'I really like Odalis! I walked past so many times until today. The door was open so I peeked in to see a nice classic bar and restaurant playing a futbol...',
#   3,
#   'Place was so-so. Nothing to write home about. Got carry out from here. Couple pupusas and some yucaca con chicharrón and a tamarindo. Not the best but not...'),
#  ('mAIdc2LPpctFFt1q7s7eEA',
#   3,
#   'I plan on filing this review out further to be fair. In general the food tasted like it all came from the same grill, and all the food tasted like each...',
#   1,
#   '.... This place is horrible. I honestly hate writing bad reviews about privately owned establishments but honestly it was all horrible here. My wife and I...',
#   5,
#   'My server was Ana and she was amazing. And the the general manager was fantastic. Poor guy is running around all over place. Customer service is special. No...'),
#  ('uFPvkGNWYcPyAIt1Ty2rNw',
#   5,
#   'I have been craving this ham for a while so I decided to get one for this New Year. After reading the reviews of customers who pre ordered how disappointed...',
#   5,
#   "I had a craving for Honey Baked Ham Company's roasted turkey for lunch and decided to stop into this Silver Spring location. Due to COVID, you must wear a...",
#   2,
#   'I ordered a ham & a Turkey from this location for thanksgiving. I preordered both. I arrived here just to find out that they were sold out of turkeys. They...'),
#  ('s5CKecz7IPjyXDaOB6lksw',
#   5,
#   'Great food and service . The place looks amazing with the renovation it underwent with open ceilings and a more modernized design.',
#   2,
#   'We dined here on Labor Day and ordered the plato parrillada for two. It was supposed to come w ribs but was not served w any. We asked and they said no....',
#   2,
#   'So the food here is amazing but customer service will vary based on your race. I went 4 times total. Once with a white woman, once with a Dominican woman...'),
#  ('iFlsULVTRJDu6zerZBUXlQ',
#   5,
#   "Amazing food, they don't skimp on the meat like other more expensive chinese takeout places while also selling it for cheaper and with pork fried rice...",
#   5,
#   'Great food and service. Very vegetarian friendly. If they forget to include an item, they make it good.',
#   3,
#   'Had the taste for Chinese Food. Decided to try this place based on the reviews. Food was just ok- meh. It was hot and fresh when I picked it up. Not...'),
#  ('J5YMUUh-lznPlug3RbL2Ww',
#   4,
#   "For the price and the amount of food, you really can't beat Blue Pearl.  Conveniently located in downtown Silver Spring, I find myself gravitating to Blue...",
#   2,
#   '$12 lunch prices and $15 dinner prices includes a drink and an all you can eat buffet. The buffet has good selections, which includes deserts, pizza, sushi,...',
#   1,
#   'Ew. Dirty. Dirty. Dirty. Horrible customer service. I only went because my family was in town, it was late and we wanted a quick, filling meal. I was very...'),
#  ('gGjN9kuRcEoLfrElsT03CA',
#   5,
#   'Ordered Thanksgiving meal from La Ferme. The food was wonderful and the service was terrific. They had a table set up outside the restaurant and I was able...',
#   2,
#   'I really wish I was writing a 5 star review instead of a 2 star review, but I was very disappointed with my experience last night.\n\nMy husband and I decided...',
#   5,
#   '**Came with a group of 30 for a journal club**\n\nAppetizer: I got the lobster bisque which was really good. It has the right about of lobster pieces....'),
#  ('BtoxY7-PkddbULg1eonr3g',
#   4,
#   "Jerry's Subs and Pizza is always a great place to stop by for either a cheese steak or a pizza.  The customer service here is pretty good, and there's a lot...",
#   3,
#   "Never ordering from there again! Jerry's is a fast food place that should be eaten after ordering! My home is 10min drive and I thought my food would come...",
#   2,
#   "I ordered takeout via Seamless.  I usually order from Manny's, but I wanted to switch it up.\n\nI ordered a burger, fries, and garlic cheese bread.\n\nThe..."),
#  ('fRlBbLhx58_aCxKut64hoQ',
#   1,
#   'Disgusting!  I ordered wings and fries for pick up.  The wings were disgusting.  The wings tasted like they were re-fried, meaning reused.  The wings were...',
#   2,
#   'I came here looking for a quick bite as I was working next door. You walk in this place and it resembles a old western bar or if you are Hispanic una...',
#   5,
#   'Love this neighborhood Tex mex restaurant.  Carmen is the bartender for this place and makes great drinks.  If you like homemade food then to will like this...'),
#  ('dE3O3PITyZfup42rXDf4tg',
#   5,
#   "We have been going to Nancy's Kitchen  more often \nsince we moved to Leisure World community . We like it \nso much, we have been going almost daily for...",
#   3,
#   'No frills breakfast place.  My wife loves this place because they make chocolate chip pancakes but I think their food is fair. I got the breakfast sandwich...',
#   1,
#   "Don't waste your time or money. \n\nI wanted to order a salad, but no vinaigrette dressing so I ordered the chicken noodle and matzo ball soup.  I counted 2..."),
#  ('_G00_l7bysiCINEOUIrvbg',
#   3,
#   'A great concept for the surrounding businesses for a quick & convenient meal, yet not so great on the food & service. \n\nAll types of Beverages, Sandwiches,...',
#   3,
#   'Stubbled across this nice looking cafe in between a office building due to a fire in my building and having to be ordered to wait outside in the mugging...',
#   2,
#   "TL;DR: I won't be back for another year or two.\n\nThe people who run and work at Sprout came to my building and peronally promoted their place by bowing..."),
#  ('ian9dhkwA6lITKF1JeSDmg',
#   5,
#   'I received excellent service and the food was spot on. Due to Covid, they offer out door sitting w/ umbrellas which drew us here. On a nice September day...',
#   4,
#   'For lunch, I decided to try a new place for Peruvian chicken. For under $9, I got a quarter chicken (dark meat) with two sides - Fried Plantains and Sweet...',
#   1,
#   'The lunch special  food was ok these review is about the CEVICHE the FISH was RAW, ceviche suppose to be cook on lime juice but instead they use artificial...'),
#  ('ReKdVdEmqTCxqXwkQDfVBg',
#   4,
#   'This is great coffee shop hidden in the medical center.Enter the parking lot and take two right turns to get to the back of the building. There is no sign...',
#   4,
#   'Found this place on a lunch break and I was delightfully surprised. First it is kinda hard to find as the actual location of the Cafe is hidden and on the...',
#   5,
#   "They have the best chicken noodle soup. It's $4.12 in total. They homemake the chicken noodle soup everyday and it's delicious"),
#  ('EBBxE1Y9AQEXwl8ORixmIw',
#   3,
#   'I came to Lucky Strike on a late Thursday morning for an outing with coworkers. Everyone seemed to have a great time bowling. There was particularly unique...',
#   1,
#   'Was very disappointed in the service and drinks here. Came at the beginning of happy hour (3pm) and they said they had already run out of 2 out of the 6 of...',
#   3,
#   "I went here back in March for a surprise birthday party and it was definitely a lot of fun! \n\nThe atmosphere is filled with loud, pop music and it's a bit..."),
#  ('PVGH1fncxeS4n8zEp908Lw',
#   5,
#   "Giving Danny's a 5/5 because it is easy to order (i.e., online), arrives within a reasonable time and tastes good and consistent each time. To me, good...",
#   3,
#   'Free parking next to the Hmart shopping center. There is also metered parking nearby as well.\n\nCalled in my order and the person who answered the phone was...',
#   1,
#   "Today was the first day that I've been disappointed in Uber Eats. Danny's Sub Shop is the reason why. I was really craving Chinese food, so I ordered..."),
#  ('sYQmoEhbkK1mFBWvBOEPRQ',
#   4,
#   'Holy pasta portions! I ordered from here on a whim once since I was grabbing lunch for several people. I ordered a bunch of stuff but the thing that stood...',
#   3,
#   'Ordered delivery. Wanted a little more than just a pizza so my girlfriend and I shared a veggie pizza (spring delight) and a chicken cheese steak sandwich....',
#   5,
#   "These guys are great. They're prompt, consistent and friendly. I've ordered from here at least 15 times and every single time they had my pizza ready on..."),
#  ('2cYBlnWBn9q4nGJrAGTmCA',
#   4,
#   "Ate in-house on 10/19/2020; from a Covid standpoint, staff wore masks and gloves, they have hand sanitizer in multiple places, there's a shield at the...",
#   4,
#   'My partner and I ordered curbside lunch: Angus beef burgers come standard with tomato, lettuce, onion, house sauce, American cheese and pickles. We added...',
#   5,
#   'We recently moved to the area and were very pleased with our carry-out. The food was immediately ready at the pick up time. The BurgerIM fries were...'),
#  ('tUAA1DP4XnX48weWBgkRoA',
#   4,
#   "Stopped by bc I was starving and man I'm glad I did!!  Tried a few crispy tacos with beef and a chips and cheese and found everything to be delicious!!  The...",
#   1,
#   "I don't like this Ay Jalisco at all , I have eaten there and the service is horrible , they take long , they are rude and the music be to loud , but today I...",
#   5,
#   "I ordered from this restaurant for the time last night. The food was delicious. I am currently eating the salmon with shrimps and it's really good. I am..."),
#  ('PTBHKX6KbVpnasszhoMLPA',
#   5,
#   'I highly recommend this place! I ordered the tacos and they were made in a very detailed way. They had all of the right ingredients. The salsa and guacamole...',
#   5,
#   'This place was amazing my parents took me here for my birthday. The food was amazing the bartender/ server help and took our orders with care recommend this...',
#   5,
#   'Last night was epic, between me and my tostada! The waitress was so sweet! They were getting ready to close when I called in and she took my order right...'),
#  ('SU4eHxNuPE__eHJmSfWPlg',
#   4,
#   'I ordered from Pizza Bolis for the first time last night. I was a little wary based on other Yelp reviews. I was pleased with our experience. Ordering...',
#   1,
#   'Legit been ordering from this establishment for years. Today I did a pick up order since I was close by. My order was not ready in the 15-20 time frame...',
#   1,
#   'Never ordering from this pizza bolis again!  The pasta shells in my stuffed shells pasta order were not all the way cooked!  The boneless wings, which...'),
#  ('D5qStQ9ID9jBGlodMBYjxw',
#   5,
#   'The food is delicious. I ordered grilled salmon my love ordered stew beef . The grilled stew beans are so yummy! \nMore importantly the staff is amazing. The...',
#   4,
#   "It's always fun when a place opens up in town.  But it's best when that place backs up their food as well.  This place def does that.  When you walk in and...",
#   5,
#   'This is one of the best places for eating good service fresh food nice and clean everything \nGood taste one of the best Latin American food,\nPara comer es...'),
#  ('I9ylGWJ8O4R9X7M1P2UyuA',
#   5,
#   'I think they opened here about three years now and always be a good fast takeout spot for my family \nSometimes the Bread is cold for takeout But if you ask...',
#   5,
#   "This location has been a lifesaver during the pandemic! I've been entertaining with their family platters. Separate servings, separate utensils and fresh...",
#   3,
#   'We have tried this location of Moby Dick a few times now and have found it to be an okay experience.\n\nWe have ordered over the phone for takeout and that...'),
#  ('lpU-hUPOFHtGOejm5g_sgA',
#   5,
#   "One of the best biryanis I've had, and they made sure to pack all sides (onions, raita, gravy) for takeout. They also include a sweet (I've gotten ladoo and...",
#   5,
#   'During the pandemic, my first time to taste food there. Really fresh and tasty! My husband lived in India for 5 years, and he said this is exactly the same...',
#   5,
#   "Ordered their Onam special for Pickup. Very tasty and delicious. Unfortunately, that was a special. They normally don't do Kerala food. Oh well."),
#  ('jmqmC_F4QGAdV_p0fiDiKw',
#   5,
#   "My new favorite local hangout! I absolutely love the decor and ambience here...it's very jazzy! Had it bookmarked for awhile and recently stumbled upon it....",
#   1,
#   'This place is absolutely horrible from Service to the food ! One thing I hate is absolutely bad service , my burger bun was " came out refrigerator" cold...',
#   5,
#   "The ambience is just beautiful. The way it's decorated inside is peaceful and they have jazz music playing too. They have live music on Fridays and..."),
#  ('fkDUi1wxPsIqcBotDtzuwQ',
#   5,
#   'Great food. Enjoyable atmosphere which makes for a great day. Definitely recommend it for a nice afternoon or evening.',
#   4,
#   'We came here for a birthday happy hour from 4-7 pm. They had $1.50 off beer but a lot of the beers ran out fast :( But we made do. The calamari, bacon...',
#   2,
#   'After seeing random advertisements and announcements on local "Going Out Guides" and "What to do this week" about this new "beer garden" to open in...'),
#  ('q_KmafURkmJKydzLd6dPhA',
#   4,
#   "I went to this place for the first time yesterday about 2pm. It's a small but chill place. They don't serve alcohol but they have beverages available. The...",
#   5,
#   "So cheap and affordable good service and good hookah I love it and I'll be sure to come back in the future! I found out about this place about 3 years ago...",
#   5,
#   "The hookha was good not great but chill place to come study or hang out with friends. The music wasn't too loud so you can talk to the person sitting next..."),
#  ('7wbNvaXOc0vKL5ULB9PTKg',
#   4,
#   'This cafe is located in my office building, I wanted to try something safe so I got the veggie pizza which was delicious. However the menu states that the...',
#   2,
#   'It\'s a "it will do" kindof place. It\'s mostly a convenience for the people in the surrounding area. The food is pretty simple and not a complicated menu....',
#   5,
#   'Mike and Calvin run the show! Easily the BEST DELI in 20817! Maybe 20814? too? Daily Specials that will make your mouth water. FAST service. I just had the...'),
#  ('84myOYvrb_4Tj6V-hkm9IQ',
#   4,
#   'Tart and citrusy are the flavors that are needed to making a meal seem light and satisfying.  Ceviches and bolivian dishes were delicious.   This was...',
#   5,
#   "I've only tried their pollo saltado, but it's very good. They have a lot of items in their menu so it's not like a typical peruvian chicken place where...",
#   1,
#   "Terrible experience. Very terrible. Went in for Father's Day to treat the dad out, and it was disastrous. Worst part is it wasn't even too busy, so they..."),
#  ('njgbQ8y-TjULTKVu18GtbQ',
#   4,
#   'The Bench offers a very good Happy Hour!!  I have been here in multiple occasions and enjoyed it every time!  I usually come to the Bench with coworkers as...',
#   3,
#   'Food and drink - with bar and restaurant and lounge seating - with TVs and a lovely view of the lake. Good amount of food options for a hotel lounge /...',
#   4,
#   'While staying at the Gaithersburg Marriott we stopped in to the bar, The Bench one day around early evening on a Saturday for a glass of wine before our...'),
#  ('gYrnbaYJCutgQidPA4t09w',
#   5,
#   "Love this place! We just moved into the building (yes, we are still going into the office) and the deli has been the best part. It's super clean, following...",
#   4,
#   'A neighborhood deli catering to the office crowd with well prepared food at average prices. 2 special things about them: 1) they have changed their menu...',
#   5,
#   'Very friendly and have a wide selection of different types of sandwiches. \n\nThe paninis are awesome!!'),
#  ('fFVec_aYEEkHEhCo7r2uvg',
#   5,
#   'my favorite pizza. Try the Lasagna and the gyro. Delicious! I love that they use Pepsi products.',
#   1,
#   "Bought a pizza through the app to pick up. When I got home I opened it up ready to watch a movie and they didn't cook it well done like I indicated and...",
#   4,
#   'This Ledo Pizza is in a strip mall in the Leisure World shopping center, a few stores down from the Giant grocery store. It was fairly easy to find, and...'),
#  ('PEs4zTHVo_0yDRwEU2aqEA',
#   5,
#   "Awesome and authentic- even if you don't like pupusas, there are other items on the menu definitely worth it- like the tacos.  Great prices",
#   5,
#   "You walk into a large seating area, since I came in around 4PM it was largely empty. I didn't really care about ambiance (I rarely do), I was there for the...",
#   1,
#   'If there would be an option for NO STAR --that would be the rating. This is not a descent place. \n\nIts a place where man are definitely treated better than...'),
#  ('fCmnPtMV6KqWAqOGz6rwQA',
#   3,
#   "Pretty cool place but service is hit or miss, like mentioned by previous Yelpers. \n\nBP's work friends invited us out. There was one Hookah ordered for the...",
#   3,
#   "I've come here multiple times for happy hour with coworkers!  Ogei's has some wonderful happy hour drink specials as well as appetizers specials!! I ordered...",
#   2,
#   "I've been going to Ogei's for a while now most of the staff was nice once i was able to get in, drinks are good, but prior to entering the security guard at..."),
#  ('EPDHuwRF1e8BuBv2GPMB9g',
#   4,
#   'After searching around on a Friday night for a place that I can get tacos, I ended up here. I ordered the shrimp tacos and plantains. Let me say this, I so...',
#   1,
#   "Salsa and chips were fairly good. Waitress, not so much. Too much to go into detail. Cheese enchilada came with no sauce. Rice was bland. Won't be going...",
#   5,
#   "What a wonderful dining experience!  We started with mixed pupusas and went to a TexMex platter. Everything's as fabulous!  We highly recommend this new..."),
#  ('y8EFLp_4adviotbBZO1KNg',
#   3,
#   'We shop here regularly. Generally the selection is okay, but I have several problems. The produce offered is limited in scope and at times  not as fresh as...',
#   4,
#   'This Giant is located right off of River Road. They have an awesome fresh fruit and vegetable section. I stop by at least once a week. The deli always has a...',
#   5,
#   'Free friendly staff... always smiling ... always improving . \nFrom all the surrounding Giants this is my favorite one. Especially there are two employees...'),
#  ('VI8_4X77eTIZy_STaI7SvQ',
#   4,
#   'The property management team at the Bolger Center changes constantly  as does the management of the Pony Express. \n\nThe bartenders and servers have been a...',
#   4,
#   'We hosted a meal for about 25 people and the service was prompt. The food quality was good, even though they mixed up a few dishes. Beers were cold. Evening...',
#   2,
#   'Where to begin? The place was very dark and under renovation. We had to ask if we could just sit anywhere. Waitress started off with getting our drinks and...'),
#  ('Pjevmllkmc2KEsTXKAbJnw',
#   4,
#   "You never know when a hotel restaurant is going to be an undiscovered gem, so I thought I would give this one a try (plus I've been craving a burger and...",
#   4,
#   'Food was excellent. The server was lovely. The prices ranged from "very good" to "whoa - that is expensive" -- both on the same brief and pretty limited on...',
#   1,
#   "Food was great but assholes wouldn't accept my cert.  Never eating there again. Place was deserted, so you'd think they want business but apparently not."),
#  ('3YK9x5aOrHxE27WKzGSw2g',
#   5,
#   'We ordered takeout during the COVID pandemic. A meat and a veggie combo. It was ready approx 30 mins after calling. Service at pickup was great. Food was...',
#   5,
#   'Amazing customer service and friendly staff. I always get the Sheger smoothie when am in town visiting and the sheger combination. There food is always...',
#   1,
#   '(Update) Received a call from the Restaurant and ammount was refunded. This still should not have happened but she assured me she would speak to her...'),
#  ('Z3HyD5hXr7krlnUuivJotw',
#   4,
#   'TPC has a great restaurant with very good food and wonderful staff. I go here about every two weeks.',
#   4,
#   'Great place, good service, delicious meals. I just wish their menu was a little more diverse but other than that this place is fabulous and definitely...',
#   5,
#   'Excellent course. Definitely need to bring your A-game as it plays tight and the rough is thick, but the course is gorgeous and in great shape. Our...'),
#  ('e3Pl9hWvdv8DaRudBdCgWg',
#   5,
#   "It simply doesn't get any better. My go to in Baltimore.  Highly recommend what a great crew and delish food!",
#   1,
#   'They were extremely under-prepared for the pre-orders they received, and ran out of bread by 5:35pm.\nWe had to wait in line for over 30 minutes just to...',
#   1,
#   'Tried the food truck for the first time today, drove 40 minutes! Decided to try it out after seeing it on the show & hearing positive things about the food...'),
#  ('d6Mp-e2S27MYC0kLnE0F1g',
#   1,
#   'F THIS PLACE. And here is why. I called ahead to see what the hours were. The girl on the phone told me 9 pm. So, we get off of our train and and our cab to...',
#   5,
#   'Great local store with cold beer and wine, it has all the essentials for after a long day of work. The owners are super friendly and they even have a...',
#   5,
#   'No frills...Love this place. Reminiscent of the bodegas in NYC and they carry my favorite beer to boot!'),
#  ('Q9_JoHtQOLQB2gyMzlfNmw',
#   5,
#   'Lovely breakfast buffet. Made to order omelettes are excellent! Smoked salmon with capers and onions - great!',
#   2,
#   "Osgood's Dining is one of two meal options for those staying at the Bolger Center.  I believe meals here are part of the standard conference package. It...",
#   5,
#   'The food is on point and have exceeded my expectations during my stay at the Bolger Hotel. AWESOME! AWESOME!'),
#  ('iGapz9M7e3uoSeFMnw5Fhw',
#   4,
#   'Hubby and I came here to this black-owned bar on a Friday. The rooftop was open and spacious - great for social distancing. We sat in a corner by the TV,...',
#   5,
#   'Capacity 75.... best thing for covid country. The place is definitely 6ft distance and the security was definitely strict about face mask and social...',
#   3,
#   "I went to Palisades rooftop for the first time last night for a friend birthday party. It's definitely a cute rooftop and it has lots of potential to be one..."),
#  ('ksJjCJRlW4Ig0Wsys0knPQ',
#   4,
#   'I ate here a few times and heard about their Easter brunch. And apparently, the hotel and kitchen is under new management and I can definitely taste the...',
#   2,
#   'This place has food quality, flavor, and creativity similar to dennys.  We got in late and were exhausted so we sat down for dinner.  The food took over 40...',
#   2,
#   'There are definitely better hotel restaurants available. The weather was miserable in Rockville today, so there was no real choice other than eating here....'),
#  ('x7DXTfzTgHfxUcyfYds4SA',
#   5,
#   "Great sandwiches, whether is a breakfast sandwich (sausage egg and cheese is soooo good) Or a nice juicy tuna for lunch. \nPrices are kinda high but it's...",
#   5,
#   "Young's deli is so fresh and delicious. My favorites are the hummus platter, Italian cold cut with extra hot pepper relish, the house panini, and the bacon...",
#   5,
#   "I have used this deli for catering at the hospital and Young's is a winner. I am getting ready to cater another lunch and they will be my choice again!"),
#  ('x6aty3EpPv7nlyanajz0Iw',
#   4,
#   '(11/18/2016)  New food truck (to us) at work, was just passing by, the menu caught our eye.  The guy working the window was very friendly, pulling the hard...',
#   5,
#   "I've eaten at this truck twice now on my lunch break down by the Inner Harbor at Pratt \n& Market Place. I was pleasantly satisfied both times and will...",
#   5,
#   'Tried this place because I was on a tight timeline and needed something quick....So glad I tried it and will be coming back.  I had the chicken kabob...'),
#  ('ie2k_eUUhVznxytOedxz6g',
#   5,
#   'My apt complex has been having food trucks come to our apt for the past few weeks and this was one of them. My husband loves bbq, so we had to order. \n\nI...',
#   3,
#   "We ordered from Smoke Stack's House of BBQ food truck while at Janemark Winery and Vineyard (see review) -- The Big Stack (ribs + brisket + chicken)...",
#   5,
#   "Best BBQ hands down! I'm from the south and every bite reminds me of home. Delicious food is my weakness for spending, yet the prices are on point and the..."),
#  ('y-Pg-KXG5Wv_z2ylaP627A',
#   4,
#   "Have had the Steak Frites here before, and it was fine. Friendly staff snd super convenient for a snowy night's stay at the Sheraton!\n\nSo maybe braised...",
#   5,
#   "Didn't know Mica's existed until I had to stay over at the Sheraton in Silver Spring.  Now that I know, I will go back to get the shrimp sauteed in a lemon...",
#   1,
#   "Seriously the worst food I've had in a long time.  I went with a friend and we started with the crab dip. There was no crab meat in the dip. It was cream..."),
#  ('h29tex_Eea17C7GBpk3eNw',
#   5,
#   'We had parked and were walking to another restaurant but it was so cold so we popped in here. Total hole in the wall dive. And it was AMAZING!! Everything...',
#   5,
#   'I am a regular here. My go to entree is the carne asada. Also, The chicken wings are good. They always have drink specials. Recently they renovated the bar....',
#   5,
#   'This is such a fun place in Wheaton. Delicious food/ cheap drinks / pool tables and a juke box to entertain. Plenty of TVs to watch sports on too.'),
#  ('CNATPQgruDWBVRjXfzT8KQ',
#   4,
#   "The Frenchman came to my office park a few weeks ago. I got L'Capitan, the deep fried chicken with cheese, cabbage and sauce on brioche. I added a fried egg...",
#   4,
#   'Yum!\n\nCame across their food truck while we were at The Winery At Bull Run. Everything on their menu looked delicious. Tried their Napoleon the Conqueror...',
#   5,
#   'The Frenchman food truck is a testimony to gluttony, and the ultimate cheat day meal. \n\nI had the Napoleon the angry. Fried chicken goodness on a brioche,...'),
#  ('fZ99lIIW1UnusxL5HVSsBQ',
#   4,
#   '(3.75) ~ Good Overall Food & Service\n\nMENU:\n** Hot Chocolate w. Chocolate Chip Marshmallows = (4) very good\n** Cinnamon Roll = (4) very good\n* Sausage, Egg...',
#   3,
#   'I ordered a catered breakfast for a staff meeting consisting of 68 people. Ally delivered the breakfast. I was impressed that she was punctual as the campus...',
#   4,
#   'Breads are excellent. \n\nSalads are fresh, and delicious, but a bit skimpy for the prices. \n\nNice to have options for single items or boxed combos....'),
#  ('ovilz4tZvbE6ynLTlGxbaQ',
#   3,
#   "COVID-19 Feedback: One of the cashiers told me that her manager won't let them wear masks, which, to me, is absolutely terrible and makes no sense....",
#   3,
#   "The store covers necessary grocery purchase needs (meats, dairy, produce, and dry shelf). I specifically come here for certain Damon's Light & Fit Greek...",
#   3,
#   'I came for Redbox ("A Simple Favor") and ended up grocery shopping. So scatterbrained! \n\nThere\'s no bakery section! And no self-checkout! What...'),
#  ('oEOSqle2v-KeEHT67h1iEQ',
#   2,
#   'This is one of my favorite places for a great sub. But the last time I went in there, right in the middle of coronavirus, the woman who checked me out at...',
#   5,
#   'The pizza, the service, the prices. They are all amazing! This place is a hidden gem and needs to be recognized. This is not a long review because it...',
#   5,
#   "I'll start off with I eat from here probably way too often, the low prices and area make it a convenient stop for lunch. Food is usually ready within 10-15..."),
#  ('L5ZqZgzXkD2MLYIDn3DOrg',
#   5,
#   "Honeybee's came to my office and I ordered their chicken teriyaki hibachi. It was delicious... as I was eating, a coworker walked past and commented that my...",
#   4,
#   "I found the truck at Shady Grove Farmer's Market today, and there was a large cluster of people around the truck. \n\nWhen we decided to order our lunch from...",
#   1,
#   'Low quality. Bad taste. Tried both crepes and entrees. Very disappointing. Go somewhere else.'),
#  ('uHmqi435T_EC-x6-sgczAw',
#   4,
#   'Another visit to this D&B!  On March 12th, 2020, right after work, decided to go to D&B to play some games.  It was kind of the start of the Coronavirus...',
#   4,
#   'We always have fun with the games but my sister believes the mac and cheese is boxed... those this theory can be debunked if a kid says it, it must be...',
#   5,
#   'We went back the next day to take advantage of the Unlimited Game and Wings.  The service was great again.  We went on a Sunday at 11:30 am and left about...'),
#  ('F7YyWA2DBMeuSyZLKRdYPA',
#   3,
#   'The first time I was there was this summer when Colombia was playing..we were looking for a spot to have Colombian food & cocktails.. it was clean had good...',
#   5,
#   'There are a few times when I write a review and I only do it if the food is good in this case 100% food super delicious made by order and u can tell they...',
#   1,
#   "Let's start with the one star is because they actually had good Colombian music. Our waitress was nice, she tried. \n\nOpening day- no empanadas. No papas..."),
#  ('9RTYTH7DQoo82u87RHFa2Q',
#   4,
#   "The. Nachos.\nI've been here a few of times and the last 2 times, I've gotten the nachos. It's a hefty portion and they don't skimp on the toppings. You...",
#   1,
#   "Terrible!     Food and drinks and customer service is lacking so much.   I'm not sure what else needs to bee said.  I really wish I would have taken pic of...",
#   1,
#   'I would certainly give them a negative 2 if I could. This was the worst experience I have ever had at any Dave and Busters. I was here for football on a...'),
#  ('cLT7wv_SM7wGjVz340pXMw',
#   4,
#   'With so many outside options I still enjoy the salad and soup bar here at Rio. Everything is very fresh and a wide variety of offerings.  You can make a...',
#   4,
#   'This should have been a quick tip:\n\nChocolate Pudding garnished with whip cream...$1.47\n\nOh yeah, sweet!',
#   5,
#   'Great variety of options...salad bar, grill, sub station, innovative ethnic entrees.  Fantastic chefs and service.'),
#  ('aFGhUWZFlamciNzCPNVznQ',
#   4,
#   "I work nearby this cafe and finally decided to give this place a try. This cafe is located in the LL of the building (didn't see any signs on the 1st...",
#   None,
#   None,
#   None,
#   None),
#  ('sHMUE-eZHThGEOgzHO-yfg',
#   4,
#   "My daughter and I wanted something simple and easy for dinner so we checked this place out. We'd never had pupsas before so we ordered five different...",
#   3,
#   "This is a very small restaurant located in the middle of a industrial / warehouse strip of buildings on Brookville Road - I'm guessing that its clientele...",
#   1,
#   'Filthy, smell like sewer water and very bad food. The waitress service is one of the most worst service I had.'),
#  ('0RXuYHzevwRAx6j903_GLg',
#   1,
#   'If I could give ZERO stars I would.  I got a Living Social coupon on 2/9/2013 for $36.00 for the delivery of 3 deliveries of two servings each....',
#   5,
#   "This food is A-mazing!  I don't know how they do it for what they charge.  I just had the blackened salmon and I am very picky about my salmon and how it is...",
#   4,
#   'The first time I ordered from them, an issue arose: the delivery driver did not make it. I then called the restaurant in the morning and the owner was...'),
#  ('tRPs30AvTOgqYqoyWa10VQ',
#   4,
#   'I work nearby and love this place. They are so warm and inviting. They always prepare my food quickly and correctly. This is no gourmet restaurant. But, you...',
#   None,
#   None,
#   None,
#   None),
#  ('uM5vi-bT8pjUxJT-IJgsuw',
#   1,
#   'I ordered through the Beyond Menu App and the order never came and the restaurant never answered the phone.   I had to call Beyond Menu and have them credit...',
#   1,
#   'The only reason this $#!+ hole gets 1 star is that is the lowest rating it can acheive. I ordered take out from here for $65 and they gave me frozen...',
#   2,
#   "I've definitely had much better. I actually ordered from here because I was in The mood for papaya salad. Got a call 10mins after I placed my order and was..."),
#  ('SRQHDjuicXeqa3zZWKTciA',
#   4,
#   'A full fledge eatery located on the lobby floor of the Chevy Chase building offering a Grill, Deli, Salad Bar, Starbucks, Sushi & Soups. \n\nThe healthy...',
#   1,
#   'Normally a pretty decent breakfast and lunch spot Where you are greeted and you feel that customer service that is usually neglected with a lot of your...',
#   3,
#   'Good food- salads, sandwiches, frozen food, sushi, fruits, breakfast, desserts, grill counter etc. I usually get my daily breakfast here. The oatmeal is...'),
#  ('-4B2Bm0hXrr043xOj85dog',
#   5,
#   'Best customer service in the Wheaton area. They have great pupusas and carne asada! The owners are super friendly. I definitely recommend this place for...',
#   1,
#   'Called here six separate times to verify how long they would be open. The first person yelled at me that it was a place of business when I simply asked when...',
#   4,
#   "I've eaten there three times and held two meetings there.  The manager and one staffer speak English.  The rest do not.  This is a great place if you speak..."),
#  ('S24F_HgCAMj5SpUoQKh_NQ',
#   4,
#   "I've tried out most of the eateries near Metro Center, and this is one of my favorites. \n\nThe food is very good with a few exceptions. Every item is always...",
#   5,
#   "The jerk chicken was great! Like a previous reviewer said, it depends on how one's sense of spicy is calibrated - I definitely could have gone hotter - but...",
#   1,
#   'They missed the mark for me... I ordered two sides because the gentleman at the registered stated they cook their fish and salmon cakes in the same grease...'),
#  ('l4QvZV6Uw-5SqsoTBv07uw',
#   2,
#   'I was served a big old disappointment salad today for lunch. Granted, it was about 2 PM when I got it, and the front counter here you order was just put...',
#   2,
#   'Man, I was looking forward to the Mediterranean menu, but just... no. The generic salad fixings were fresh, but the good news ends at friendly service. The...',
#   4,
#   "I don't get the one star review.  In my experience with a combination Chicken & Lamb Kabob Platter most recently and a Steak & Cheese sub previously, all..."),
#  ('mD6OnxNHMfKyRTmEYDuXTw',
#   5,
#   "This truck is fire!!! It's truly food for your soul! I've had the fried chicken, fried fish, half smoke, corn on the cobb, baked beans, collard greens, mac...",
#   5,
#   'This is a great truck and idea for this area. Rodney fills a badly needed gap in southern soul food. Nothing is bad. But my favorites are the fried chicken...',
#   1,
#   'Tried going repeatedly and not even a sign...did they close? Just bought a certificate for it, was told it was only open on weekends and no luck. Called the...'),
#  ('5UtO2yZ7DhK5pZ3KxZv7Wg',
#   4,
#   "This is hard to find it's in Glen Echo Park. It's behind the merry-go-round so you must really look for it. Good croissants excellent even. Selection was...",
#   3,
#   'Things I love: Moose tracks ice cream, nice baked goods, Stash tea, and especially Kevin, the super-personable guy who is always there in the...',
#   3,
#   "It's great that Praline provides some of its baked and lunch offerings through its satellite base in Glen Echo Park. It's a bit ad hoc and disorganized, but..."),
#  ('l0prEdAqMFvQXRm1dHmIEA',
#   1,
#   '(Original review 4/10/2013)\n\nRun by contractor I.L. Creations, operator of weigh-and-pay-buffet employee cafeterias in many Federal office buildings in the...',
#   None,
#   None,
#   None,
#   None),
#  ('jtN1g6nvsQIubYFDt8OYaw',
#   1,
#   "Foolish me.  I thought things might get better.  I'm glad that there are other offerings in the neighborhood now.  It's time for this place to go out of...",
#   None,
#   None,
#   None,
#   None),
#  ('4RTWtfGw-QNL7pYj6rMpAQ',
#   5,
#   'The lamb choma and samosas are really good. The owners are very nice and welcoming.  Drinks were great too.',
#   2,
#   "It is a dive and the women  try to dress \nWith a sex look and it don't look good",
#   2,
#   'A small group of West Africans and I were looking for a place to go on a Friday night, maybe have a few beers, listen to some African music, and do a little...'),
#  ('joY2tjvlNqrdPfk0UTW4IQ',
#   1,
#   'Do not order the Mondongo soup is horrible and taste nasty and it was reheated I could not believe they serve this to people. The environment is mainly men...',
#   1,
#   "It's degrading I don't understand in the middle of Wheaton they have a place like that  a BURDELO staff  in mini-skirts drinking with costumers. I went with...",
#   4,
#   "Yum! Seriously. Excellent papusas (I got them just with cheese). Some caveats: if you're a vegetarian, it may be a little difficult to find much on the..."),
#  ('AZQn_LIn650udstIkfsi8g',
#   1,
#   "Fiancée asked for the wine list, but after she had a chance to look it over, asked if they had any beer on tap instead. Which they didn't. She leaned over...",
#   3,
#   'Re-visited Capital Bleu after 6 months and have to downgrade a star due to service.  There is one waitress and one hostess for the restaurant and this...',
#   1,
#   "This place is just completely ridiculous! The menu prices are astronomical for the quality of food you get. I just can't say this more straight forward-..."),
#  ('QJrfHhz7XecrmFMcPXGljQ',
#   1,
#   "Why don't we have a zero star. This place is dingy as hell. It's actually a house transformed into a club. Looks like the place you will most likely loose...",
#   4,
#   "My first time at Betty's was great. We ordered drinks and a hookah, which both came promptly. We wanted to Love tables and they quickly accommodated us....",
#   1,
#   'So my friends and I were seated at a table for quite some time, having placed our hookah and drink orders already, when the server came back and demanded...'),
#  ('xENeN16taYu0UkqNr_XyOQ',
#   5,
#   "I happened to have a meeting at the TASC building today. Which apparently has food trucks on Wednesday 's. After looking at my options I settled on this...",
#   1,
#   'Tried their chicken and beef shawarma plates. Both were disappointing. Their meats are cooked using either a slow cooker or a pressure cooker with some...',
#   1,
#   'Wanted to support them in the neighborhood - friendly service.\nOrdered ribeye Sharwarna sandwich and baklava\nSandwich was soggy, very little beef that...')]

# %%
Rev_df = pd.DataFrame(total_data, columns = ['id','Rating_1', 'Review_1', 'Rating_2', 'Review_2', 'Rating_3', 'Review_3'])

# %%
Rev_df
# Out:
#                          id  Rating_1  \
# 0    14Z5fHYBRI8RLwTJGBbY6w         5
# 1    MPPROfyyB9KGRlVO2DB3dA         5
# 2    LbPFrZqFjc8TTcxkehfjRw         5
# 3    361TL_CyO-4CuR4_KN7pKQ         5
# 4    BVpWHObDjpEc4AerPfMLOg         3
# ..                      ...       ...
# 104  4RTWtfGw-QNL7pYj6rMpAQ         5
# 105  joY2tjvlNqrdPfk0UTW4IQ         1
# 106  AZQn_LIn650udstIkfsi8g         1
# 107  QJrfHhz7XecrmFMcPXGljQ         1
# 108  xENeN16taYu0UkqNr_XyOQ         5
#
#                                               Review_1  Rating_2  \
# 0    Ok, so in the days of well now you worry about...       5.0
# 1    I came here for my birthday happy hour just my...       4.0
# 2    I LOVE SPROUT. \n\nFood: 5/5 Service: 5/5 \n\n...       3.0
# 3    Maria and her team pulled out all the stops to...       1.0
# 4    The Manager sells stale produce and over charg...       3.0
# ..                                                 ...       ...
# 104  The lamb choma and samosas are really good. Th...       2.0
# 105  Do not order the Mondongo soup is horrible and...       1.0
# 106  Fiancée asked for the wine list, but after she...       3.0
# 107  Why don't we have a zero star. This place is d...       4.0
# 108  I happened to have a meeting at the TASC build...       1.0
#
#                                               Review_2  Rating_3  \
# 0    We have ordered from here several times during...       1.0
# 1    I've been here a few times and had a good expe...       5.0
# 2    I really want to say you should come out of yo...       3.0
# 3    Ok I don't even know how to begin. First of al...       4.0
# 4    Excellent coffee to go (especially loved the c...       2.0
# ..                                                 ...       ...
# 104  It is a dive and the women  try to dress \nWit...       2.0
# 105  It's degrading I don't understand in the middl...       4.0
# 106  Re-visited Capital Bleu after 6 months and hav...       1.0
# 107  My first time at Betty's was great. We ordered...       1.0
# 108  Tried their chicken and beef shawarma plates. ...       1.0
#
#                                               Review_3
# 0    I came to pick a Grubhub order and one of the ...
# 1    Pre-COVID, my husband and I enjoyed walking ne...
# 2    This place just officially opened last week (a...
# 3    This place was great for grab and go. No frill...
# 4    The coffee was good but my cheese danish was c...
# ..                                                 ...
# 104  A small group of West Africans and I were look...
# 105  Yum! Seriously. Excellent papusas (I got them ...
# 106  This place is just completely ridiculous! The ...
# 107  So my friends and I were seated at a table for...
# 108  Wanted to support them in the neighborhood - f...
#
# [109 rows x 7 columns]

# %%
Rev_df.to_csv('md_reviews')
